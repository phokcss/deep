# %%
# !unzip -n "/workspace/colab/pen_erazer.zip" -d "/workspace/colab/pen_erazer"
# Out:
# Archive:  /workspace/colab/pen_erazer.zip

# %%
from keras.utils import load_img
from keras.utils import img_to_array
from keras.preprocessing.image import ImageDataGenerator
import matplotlib.pyplot as plt
import numpy as np
EPOCHS = 300
BATCH_SIZE = 50
IMG_HEIGHT = 150
IMG_WIDTH = 150

train_dir ="/workspace/colab/pen_erazer/pen_erazer/train"
valid_dir = "/workspace/colab/pen_erazer/pen_erazer/validation"

train_datagen=ImageDataGenerator(rescale=1./255.0,rotation_range=40,width_shift_range=0.3,height_shift_range=0.3,zoom_range=0.2,horizontal_flip=True)
valid_datagen=ImageDataGenerator(rescale=1./255.0)

train_generator=train_datagen.flow_from_directory(train_dir,target_size=(IMG_HEIGHT,IMG_WIDTH),batch_size=BATCH_SIZE,class_mode='binary')
valid_generator=valid_datagen.flow_from_directory(valid_dir,target_size=(IMG_HEIGHT,IMG_WIDTH),batch_size=BATCH_SIZE,class_mode='binary')


train_num = train_generator.samples
valid_num = valid_generator.samples
# Out:
# Found 150 images belonging to 2 classes.
# Found 30 images belonging to 2 classes.

# %%
from keras import backend as K
def m_recall(y_target,y_predict):
    true_positives=K.sum(K.round(y_target*y_predict))
    all_positives=K.sum(y_target)
    recall=true_positives/(all_positives+0.0000001)
    return recall
def m_precision(y_target,y_predict):
    true_positives=K.sum(K.round(y_target*y_predict))
    predicted_positives=K.sum(K.round(y_predict))
    recall=true_positives/(predicted_positives+0.0000001)
    return recall
def m_f1(y_target,y_predict):
    precision=m_precision(y_target,y_predict)
    recall=m_recall(y_target,y_predict)
    return 2*((precision*recall)/(precision+recall+0.0000001))
from keras import models
from keras.metrics import AUC

metric_list=['accuracy',m_recall,m_precision,m_f1,AUC(from_logits=True)]
# Out:
# 2022-12-20 03:33:19.975719: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 AVX512F AVX512_VNNI FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-12-20 03:33:20.446330: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9650 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 2080 Ti, pci bus id: 0000:19:00.0, compute capability: 7.5

# %%
img=load_img('/workspace/colab/pen_erazer/pen_erazer/train/pen/pen (1).jpg')

data=img_to_array(img)
img_data=np.expand_dims(data,axis=0)
sample_datagen=ImageDataGenerator(horizontal_flip=True,vertical_flip=True)
train_sample_iter=sample_datagen.flow(img_data,batch_size=1)

# %%
print(img_data.shape)
print(data.shape)
# Out:
# (1, 3024, 4032, 3)
# (3024, 4032, 3)

# %%
fig=plt.figure(figsize=(12,12))
for i in range(9):
    plt.subplot(3,3,i+1)
    batch=next(iter(train_sample_iter))
    image=batch[0].astype('uint8')
    plt.imshow(image)
plt.show()

# %%
from keras import models
from keras import layers
from keras.applications import VGG16
VGG16_base=VGG16(weights='imagenet',include_top=False,input_shape=(150,150,3))
VGG16_base.trainable=False
model=models.Sequential(name='pen_erazer_VGG16')
model.add(VGG16_base)
model.add(layers.Flatten())
model.add(layers.Dense(512,activation='softmax',name='Output'))
model.add(layers.Dense(1,activation='sigmoid',name='FC_Layer2_Output'))
model.compile(loss='binary_crossentropy',optimizer='adam',metrics=metric_list)
model.summary()
# Out:
# Model: "pen_erazer_VGG16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  vgg16 (Functional)          (None, 4, 4, 512)         14714688
#
#  flatten (Flatten)           (None, 8192)              0
#
#  Output (Dense)              (None, 512)               4194816
#
#  FC_Layer2_Output (Dense)    (None, 1)                 513
#
# =================================================================
# Total params: 18,910,017
# Trainable params: 4,195,329
# Non-trainable params: 14,714,688
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping
ES_Callback = EarlyStopping(monitor='m_f1', patience=30)

history= model.fit(train_generator,steps_per_epoch=train_num//BATCH_SIZE, epochs=EPOCHS, validation_data=valid_generator, callbacks=[ES_Callback])
# Out:
# Epoch 1/300
# 2022-12-20 03:33:41.976879: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8600
# 3/3 [==============================] - 14s 4s/step - loss: 0.6940 - accuracy: 0.4933 - m_recall: 0.0000e+00 - m_precision: 0.0000e+00 - m_f1: 0.0000e+00 - auc: 0.5000 - val_loss: 0.6884 - val_accuracy: 0.5000 - val_m_recall: 0.0000e+00 - val_m_precision: 0.0000e+00 - val_m_f1: 0.0000e+00 - val_auc: 0.5000
# Epoch 2/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.6872 - accuracy: 0.5667 - m_recall: 0.1328 - m_precision: 0.6667 - m_f1: 0.2012 - auc: 0.5333 - val_loss: 0.6763 - val_accuracy: 0.9667 - val_m_recall: 1.0000 - val_m_precision: 0.9375 - val_m_f1: 0.9677 - val_auc: 0.8667
# Epoch 3/300
# 3/3 [==============================] - 10s 4s/step - loss: 0.6764 - accuracy: 0.8733 - m_recall: 0.7622 - m_precision: 0.9841 - m_f1: 0.8585 - auc: 0.8362 - val_loss: 0.6626 - val_accuracy: 0.9667 - val_m_recall: 1.0000 - val_m_precision: 0.9375 - val_m_f1: 0.9677 - val_auc: 1.0000
# Epoch 4/300
# 3/3 [==============================] - 10s 4s/step - loss: 0.6680 - accuracy: 0.8800 - m_recall: 0.7928 - m_precision: 0.9444 - m_f1: 0.8576 - auc: 0.9157 - val_loss: 0.6555 - val_accuracy: 0.9667 - val_m_recall: 1.0000 - val_m_precision: 0.9375 - val_m_f1: 0.9677 - val_auc: 0.9689
# Epoch 5/300
# 3/3 [==============================] - 10s 4s/step - loss: 0.6628 - accuracy: 0.9200 - m_recall: 0.8629 - m_precision: 0.9673 - m_f1: 0.9114 - auc: 0.9391 - val_loss: 0.6493 - val_accuracy: 0.9667 - val_m_recall: 1.0000 - val_m_precision: 0.9375 - val_m_f1: 0.9677 - val_auc: 0.9867
# Epoch 6/300
# 3/3 [==============================] - 10s 4s/step - loss: 0.6591 - accuracy: 0.9133 - m_recall: 0.8884 - m_precision: 0.9274 - m_f1: 0.9048 - auc: 0.9514 - val_loss: 0.6434 - val_accuracy: 1.0000 - val_m_recall: 1.0000 - val_m_precision: 1.0000 - val_m_f1: 1.0000 - val_auc: 1.0000
# Epoch 7/300
# 3/3 [==============================] - 10s 4s/step - loss: 0.6555 - accuracy: 0.9000 - m_recall: 0.8542 - m_precision: 0.9415 - m_f1: 0.8945 - auc: 0.9608 - val_loss: 0.6397 - val_accuracy: 1.0000 - val_m_recall: 1.0000 - val_m_precision: 1.0000 - val_m_f1: 1.0000 - val_auc: 1.0000
# Epoch 8/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.6480 - accuracy: 0.9733 - m_recall: 0.9575 - m_precision: 0.9861 - m_f1: 0.9715 - auc: 0.9896 - val_loss: 0.6377 - val_accuracy: 1.0000 - val_m_recall: 1.0000 - val_m_precision: 1.0000 - val_m_f1: 1.0000 - val_auc: 1.0000
# Epoch 9/300
# 3/3 [==============================] - 12s 4s/step - loss: 0.6484 - accuracy: 0.9400 - m_recall: 0.9445 - m_precision: 0.9375 - m_f1: 0.9404 - auc: 0.9763 - val_loss: 0.6340 - val_accuracy: 1.0000 - val_m_recall: 1.0000 - val_m_precision: 1.0000 - val_m_f1: 1.0000 - val_auc: 1.0000
# Epoch 10/300
# 3/3 [==============================] - 10s 4s/step - loss: 0.
300
# 3/3 [==============================] - 11s 4s/step - loss: 0.6059 - accuracy: 0.9867 - m_recall: 0.9877 - m_precision: 0.9825 - m_f1: 0.9847 - auc: 0.9995 - val_loss: 0.5972 - val_accuracy: 1.0000 - val_m_recall: 1.0000 - val_m_precision: 1.0000 - val_m_f1: 1.0000 - val_auc: 1.0000
# Epoch 28/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.6014 - accuracy: 0.9933 - m_recall: 0.9848 - m_precision: 1.0000 - m_f1: 0.9922 - auc: 0.9998 - val_loss: 0.5954 - val_accuracy: 1.0000 - val_m_recall: 1.0000 - val_m_precision: 1.0000 - val_m_f1: 1.0000 - val_auc: 1.0000
# Epoch 29/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.6098 - accuracy: 0.9333 - m_recall: 0.8877 - m_precision: 0.9833 - m_f1: 0.9315 - auc: 0.9958 - val_loss: 0.5937 - val_accuracy: 1.0000 - val_m_recall: 1.0000 - val_m_precision: 1.0000 - val_m_f1: 1.0000 - val_auc: 1.0000
# Epoch 30/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.6049 - accuracy: 0.9667 - m_recall: 0.9615 - m_precision: 0.9734 - m_f1: 0.9660 - auc: 0.9903 - val_loss: 0.5928 - val_accuracy: 1.0000 - val_m_recall: 1.0000 - val_m_precision: 1.0000 - val_m_f1: 1.0000 - val_auc: 1.0000
# Epoch 31/300
# 3/3 [==============================] - 11s 4s/step - loss: 0.6036 - accuracy: 0.9667 - m_recall: 0.9855 - m_precision: 0.9492 - m_f1: 0.9668 - auc: 0.9967 - val_loss: 0.5911 - val_accuracy: 1.0000 - val_m_recall: 1.0000 - val_m_precision: 1.0000 - val_m_f1: 1.0000 - val_auc: 1.0000

# %%
import matplotlib.pyplot as plt

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(loss) + 1)

plt.plot(epochs, loss, 'b', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.ylim([0, 2])
plt.show()

# %%
import matplotlib.pyplot as plt

acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'b', label='Training accuracy')
plt.plot(epochs, val_acc, 'r', label='Validation accuracy')
plt.title('Training and validation accuracy')
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.legend()
plt.ylim([0.5, 1.1])
plt.show()

# %%
test_dir="/workspace/colab/pen_erazer/pen_erazer/test"
test_datagen=ImageDataGenerator(rescale=1./255.0)
test_generator=test_datagen.flow_from_directory(test_dir,target_size=(150,150),color_mode="rgb",batch_size=10,class_mode='binary')
test_num=test_generator.samples
# Out:
# Found 21 images belonging to 2 classes.

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
from keras.metrics import AUC
test_image,test_label=next(iter(test_generator))
model.evaluate(test_image,test_label)

test_pred=model.predict(test_image)
fpr,tpr,thresholds=roc_curve(test_label,test_pred)

m=AUC(num_thresholds=200)
m.update_state(test_label,test_pred)
# Out:
# 1/1 [==============================] - 0s 426ms/step - loss: 0.5900 - accuracy: 1.0000 - m_recall: 1.0000 - m_precision: 1.0000 - m_f1: 1.0000 - auc: 1.0000
# 1/1 [==============================] - 0s 137ms/step

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
test_image,test_label=next(iter(test_generator))
model.evaluate(test_image,test_label)

test_pred=model.predict(test_image)
fpr,tpr,thresholds=roc_curve(test_label,test_pred)

m=AUC(num_thresholds=200)
m.update_state(test_label,test_pred)
plt.figure(1)
plt.plot([0,1],[0,1],'k--')
plt.plot(fpr,tpr,label='(area={:.3f})'.format(m.result()))
plt.xlabel('False positive rate')
plt.ylabel('True positive rate')
plt.title('ROC curve')
plt.legend(loc='best')
plt.show
# Out:
# 1/1 [==============================] - 0s 33ms/step - loss: 0.5911 - accuracy: 1.0000 - m_recall: 1.0000 - m_precision: 1.0000 - m_f1: 1.0000 - auc: 1.0000
# 1/1 [==============================] - 0s 19ms/step
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
class_names=['erazer','pen']
test_pred=((test_pred>0.5).astype("int32")).flatten()

fig =plt.figure(figsize=(12,6))
for i in range(8):
    ax=fig.add_subplot(2,4,i+1)
    ax.imshow(test_image[i,:],cmap=plt.cm.gray_r)
    if test_pred[i]==test_label[i]:
        ax.text(3,17,class_names[test_pred[i]],color='yellow',fontsize=14)
    else:
        ax.text(3,17,class_names[test_pred[i]],color='red',fontsize=14)
